# %%
from random import randrange

def display_board(board):
    # The function accepts one parameter containing the board's current status
    # and prints it out to the console.
    print(f"""+-------+-------+-------+
|       |       |       |
|   {board[0][0]}   |   {board[0][1]}   |   {board[0][2]}   |
|       |       |       |
+-------+-------+-------+
|       |       |       |
|   {board[1][0]}   |   {board[1][1]}   |   {board[1][2]}   |
|       |       |       |
+-------+-------+-------+
|       |       |       |
|   {board[2][0]}   |   {board[2][1]}   |   {board[2][2]}   |
|       |       |       |
+-------+-------+-------+""")


def enter_move(board):
    # The function accepts the board current status, asks the user about their move, 
    # checks the input and updates the board according to the user's decision.
    while True:   
        human=int(input("Enter your move: "))
        if human>0 and human<10:
            for iter in board:
                if human in iter:
                    return human    
            print("Used Spaces")
        else:
            print("Please input from range 1 to 9")


def make_list_of_free_fields(board,user):
    # The function browses the board and builds a list of all the free squares; 
    # the list consists of tuples, while each tuple is a pair of row and column numbers.
    global i
    i+=1
    if i%2==0:
        player='X'
    else:
        player='O'
    if user == 1:
        board[0][0]=player
    if user == 2:
        board[0][1]=player
    if user == 3:
        board[0][2]=player
    if user == 4:
        board[1][0]=player
    if user == 5:
        board[1][1]=player
    if user == 6:
        board[1][2]=player
    if user == 7:
        board[2][0]=player
    if user == 8:
        board[2][1]=player
    if user == 9:
        board[2][2]=player
    return board

#     if user == 1:
#         if board[0][0]!='O' and board[0][0]!='X':
#             board[0][0]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 2:
#         if board[0][1]!='O' and board[0][1]!='X':
#             board[0][1]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 3:
#         if board[0][2]!='O' and board[0][2]!='X':
#             board[0][2]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 4:
#         if board[1][0]!='O' and board[1][0]!='X':
#             board[1][0]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 5:
#         if board[1][1]!='O' and board[1][1]!='X':
#             board[1][1]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 6:
#         if board[1][2]!='O' and board[1][2]!='X':
#             board[1][2]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 7:
#         if board[2][0]!='O' and board[2][0]!='X':
#             board[2][0]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 8:
#         if board[2][1]!='O' and board[2][1]!='X':
#             board[2][1]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     if user == 9:
#         if board[2][2]!='O' and board[2][2]!='X':
#             board[2][2]=player
#         else:    
#             print("Used spaces")
#             return enter_move(board)
#     return board


def victory_for(board):
    # The function analyzes the board status in order to check if 
    # the player using 'O's or 'X's has won the game
    #O
    if board[0][0]=='O' and board[0][1]=='O' and board[0][2]=='O':#Horizontal
        print("Human WINS")
        return True
    if board[1][0]=='O' and board[1][1]=='O' and board[1][2]=='O':
        print("Human WINS")
        return True
    if board[2][0]=='O' and board[2][1]=='O' and board[2][2]=='O':
        print("Human WINS")
        return True
    if board[0][0]=='O' and board[1][1]=='O' and board[2][2]=='O':#Cross
        print("Human WINS")
        return True
    if board[0][2]=='O' and board[1][1]=='O' and board[2][0]=='O':
        print("Human WINS")
        return True
    if board[0][0]=='O' and board[1][0]=='O' and board[2][0]=='O':#Vertical
        print("Human WINS")
        return True
    if board[0][1]=='O' and board[1][1]=='O' and board[2][1]=='O':
        print("Human WINS")
        return True
    if board[0][2]=='O' and board[1][2]=='O' and board[2][2]=='O':
        print("Human WINS")
        return True
    #X
    if board[0][0]=='X' and board[0][1]=='X' and board[0][2]=='X':#Horizontal
        print("Computer WINS")
        return True
    if board[1][0]=='X' and board[1][1]=='X' and board[1][2]=='X':
        print("Computer WINS")
        return True
    if board[2][0]=='X' and board[2][1]=='X' and board[2][2]=='X':
        print("Computer WINS")
        return True
    if board[0][0]=='X' and board[1][1]=='X' and board[2][2]=='X':#Cross
        print("Computer WINS")
        return True
    if board[0][2]=='X' and board[1][1]=='X' and board[2][0]=='X':
        print("Computer WINS")
        return True
    if board[0][0]=='X' and board[1][0]=='X' and board[2][0]=='X':#Vertical
        print("Computer WINS")
        return True
    if board[0][1]=='X' and board[1][1]=='X' and board[2][1]=='X':
        print("Computer WINS")
        return True
    if board[0][2]=='X' and board[1][2]=='X' and board[2][2]=='X':
        print("Computer WINS")
        return True
    return False

def draw_move(board):
    # The function draws the computer's move and updates the board.
    while True:
        comp=randrange(1,10)
        for iter in board:
            if comp in iter:
                return comp

b=[[1,2,3],[4,5,6],[7,8,9]]
i=0
display_board(b)
while True:
    user1=enter_move(b)
    b=make_list_of_free_fields(b,user1)
    display_board(b)
    who=victory_for(b)
    if who:
        break
    user2=draw_move(b)
    b=make_list_of_free_fields(b,user2)
    display_board(b)
    who=victory_for(b)
    if who:
        break
# Out:
# +-------+-------+-------+
# |       |       |       |
# |   1   |   2   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   5   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   8   |   9   |
# |       |       |       |
# +-------+-------+-------+
# Enter your move: 1
# +-------+-------+-------+
# |       |       |       |
# |   O   |   2   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   5   |   6   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   7   |   8   |   9   |
# |       |       |       |
# +-------+-------+-------+
# +-------+-------+-------+
# |       |       |       |
# |   O   |   2   |   3   |
# |       |       |       |
# +-------+-------+-------+
# |       |       |       |
# |   4   |   5   |   6   |
# |       |       |       |
# ...
